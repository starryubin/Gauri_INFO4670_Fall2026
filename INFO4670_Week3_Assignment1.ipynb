# %% [markdown]
# <a href="https://colab.research.google.com/github/starryubin/Gauri_INFO4670_Fall2026/blob/main/INFO4670_Week3_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1 — Making Sense of Northgate through Visualization
# **INFO 4670 · Data Analysis and Knowledge Discovery**  ·  **Due: Sunday, 11:59 PM**
#
# **Name:** Gauri Adhappan    **Date:** 9/6/26
#
# **The situation.** The Provost's question stands: *which students are struggling, and can we see it earlier?* This week you answer it the way analysts do — not by reading rows, but by drawing the data. Every chart below is built by **adapting code from the Guided notebook**; the intellectual work is choosing the right chart and reading it honestly.
#
# **For every chart you make, you must:**
# 1. **Choose** the chart type that fits the variable(s) and the question.
# 2. **Build** it in Colab from the Northgate files.
# 3. **Label** it fully — title, axis labels, and units/legend. *An unlabeled chart is an unfinished chart.*
# 4. **Write a STAR story** underneath it — Scope · Track · Articulate · Respond (defined on the Concepts deck).
#
# **How to work:** run Setup and Load first. Then, for each question, copy the closest cell from the Guided notebook into the empty cell, adapt it, and fill in the STAR cell below it.
#
# **Submit:** push this notebook to GitHub and submit the **GitHub link** in Canvas. (See the setup doc: *Colab_GitHub_Setup_INFO4670_Fall2026*.)

# %% [markdown]
# ## Setup — run this first (you don't need to change it)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Northgate house style (optional, but keeps your charts consistent)
NAVY = "#22303A"
RUST = "#C0562F"
sns.set_theme(style="whitegrid")
plt.rcParams["figure.figsize"]   = (8, 5)
plt.rcParams["axes.titlesize"]   = 13
plt.rcParams["axes.titleweight"] = "bold"

# %% [markdown]
# ## Load the data — run this, then look before you plot

# %%
# STEP 1 — get the data into this notebook. Pick ONE option, then run.

DATA_DIR = "."   # OPTION 2 (default) · drag the 3 CSVs into the file panel on the left

# OPTION 1 · read from Google Drive — uncomment and edit the path:
# from google.colab import drive
# drive.mount("/content/drive")
# DATA_DIR = "/content/drive/MyDrive/.../Data"

import os
students = pd.read_csv(os.path.join(DATA_DIR, "student_records.csv"))
weekly   = pd.read_csv(os.path.join(DATA_DIR, "weekly_activity.csv"))
students.head()
# Out:
#   student_id                   major  age      housing  commute_miles  \
# 0  NU-101508            Data Science   27   Off-Campus            7.6
# 1  NU-102438   Learning Technologies   25  With Family           14.3
# 2  NU-102385   Learning Technologies   26  With Family            3.4
# 3  NU-100767          Cyber Security   22    On-Campus           23.7
# 4  NU-106054  Information Technology   21   Off-Campus            2.3
#
#    work_hours_per_week  advisor_meetings  credits_attempted  final_gpa  \
# 0                   15                 1                 81       1.86
# 1                   35                 1                100       2.06
# 2                   18                 9                 77       3.41
# 3                   40                 1                 65       1.73
# 4                   20                 4                 59       2.37
#
#    study_hours_reported enrollment_date  dropped_out
# 0                   NaN      2023-09-13            1
# 1                   9.5      2023-10-19            0
# 2                  19.1      11/16/2022            0
# 3                   8.1      2024-05-03            0
# 4                   6.6      10/24/2022            0

# %%
# how many rows, which columns, what types?
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2027 entries, 0 to 2026
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            2027 non-null   object
#  1   major                 2027 non-null   object
#  2   age                   2027 non-null   int64
#  3   housing               2027 non-null   object
#  4   commute_miles         2027 non-null   float64
#  5   work_hours_per_week   2027 non-null   int64
#  6   advisor_meetings      2027 non-null   int64
#  7   credits_attempted     2027 non-null   int64
#  8   final_gpa             2027 non-null   float64
#  9   study_hours_reported  1772 non-null   float64
#  10  enrollment_date       2027 non-null   object
#  11  dropped_out           2027 non-null   int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 190.2+ KB

# %% [markdown]
# # Part A — Guided questions
# Build **one chart per question**. Each maps to one chart family from this week. Copy the closest Guided-notebook cell, adapt it, label it, then write its STAR story.

# %% [markdown]
# ### Q1 · One quantitative variable
# **How many hours per week do Northgate students work?** Describe what's typical, how spread out it is, and whether anyone stands apart.
# → *histogram* (add a *box plot* if it helps). Column: `work_hours_per_week` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()

sns.histplot(data=students, x="work_hours_per_week", color=NAVY, ax=ax)

ax.set_title("Distribution of Weekly Work Hours Among Northgate Students")
ax.set_xlabel("Work Hours per Week (hours)")
ax.set_ylabel("Number of Students")

plt.show()

# %% [markdown]
# **STAR story — Q1** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# Scope: This chart shows the weekly work hours for all Northgate students in the student records data.
#
# Track: I am looking at how many hours students typically work, how spread out the hours are, and whether any students stand out.
#
# Articulate: Most students work between about 10 and 30 hours per week, with a lot of students around 15–20 hours. The values range from 0 to 40 hours, showing that students have fairly different work schedules.
#
# Respond: The multiple peaks are interesting because there is not one single work-hour level that describes everyone. I would next compare work hours with GPA or dropout status to see whether working more hours is related to struggling academically.

# %% [markdown]
# ### Q2 · One categorical variable
# **How does enrollment compare across majors?**
# → *sorted bar chart*. Column: `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()

sns.countplot(
    data=students,
    x="major",
    order=students["major"].value_counts().index,
    ax=ax
)

ax.set_title("Enrollment Across Northgate Majors")
ax.set_xlabel("Major")
ax.set_ylabel("Number of Students")

plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# **STAR story — Q2** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# Scope: This chart shows the number of Northgate students enrolled in each major, using the major column from the student records.
#
# Track: I am answering how enrollment compares across the different majors and which majors have the most and fewest students.
#
# Articulate: Cyber Security has the largest enrollment, with over 500 students. Data Science, Information Science, and Information Technology each have around 280 students. Business Analytics and Learning Technologies have fewer students. Overall, enrollment is not evenly distributed across the majors.
#
# Respond: The last four majors appear to be duplicate versions of majors already listed, such as "Cyber Security" vs "Cyber Security," "Data Science" vs "DataScience," and "Information Technology" vs "Info Technology." This looks like a data-quality issue that could make the enrollment counts misleading. I would look at the exact spelling and formatting of the major values and investigate whether these categories should be combined before using this data for further analysis.

# %% [markdown]
# ### Q3 · A quantity, split by category
# **Does final GPA differ across majors?** Read the exceptions, not just the boxes.
# → *box plot per major*. Columns: `final_gpa` and `major` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()

sns.boxplot(
    data=students,
    x="major",
    y="final_gpa",
    ax=ax
)

ax.set_title("Final GPA Across Northgate Majors")
ax.set_xlabel("Major")
ax.set_ylabel("Final GPA")

plt.xticks(rotation=45, ha="right")
plt.show()

# %% [markdown]
# **STAR story — Q3** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# Scope: This chart shows the distribution of final_gpa for Northgate students, separated by their major.
#
# Track: I am answering whether final GPA differs across majors by comparing the typical GPA, spread, and unusual GPA values for each major.
#
# Articulate: The typical GPA is fairly similar across most majors, generally around 2.2–2.4. The boxes show that there is quite a bit of variation within each major. Most majors have students with GPAs reaching around 3.5–4.0, while the lower end varies between majors.
#
# Respond: There are several GPA values at or near 0.0, along with a few other low outliers. Also, the duplicate major names appear again here, which could split the same major into separate groups and affect the comparison. I would next investigate those zero GPAs and the inconsistent major names to determine whether they represent real students/results or data-quality problems.

# %% [markdown]
# ### Q4 · Two quantitative variables
# **Is there a relationship between how far students commute and their final GPA?** Remember: *association is not causation.*
# → *scatterplot with a trend line*. Columns: `commute_miles` and `final_gpa` (from `students`).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()

sns.regplot(
    data=students,
    x="commute_miles",
    y="final_gpa",
    scatter_kws={"alpha": 0.5},
    line_kws={"color": RUST},
    ax=ax
)

ax.set_title("Commute Distance and Final GPA")
ax.set_xlabel("Commute Distance (miles)")
ax.set_ylabel("Final GPA")

plt.show()

# %% [markdown]
# **STAR story — Q4** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# Scope: This chart compares commute distance in miles with final GPA for Northgate students.
#
# Track: I am seeing whether students with longer commutes tend to have lower GPAs.
#
# Articulate: The chart shows a negative association between commute distance and final GPA. Students with shorter commutes make up most of the data and have a wide range of GPAs, while students with longer commutes tend to have lower GPAs. The trend line falls from about 2.5 GPA at 0 miles to about 0.8 GPA at 80 miles. There is substantial variation, so commute distance does not predict an individual student's GPA very well.
#
# Respond: The 0.0 GPAs and very long commutes are worth investigating. I would look at those students' other information such as work hours or major next. This chart shows an association but does not prove that commuting causes lower GPA.

# %% [markdown]
# ### Q5 · Over time
# **How does student engagement change across the semester?**
# → *line chart* of average weekly activity. Use the `weekly` table: `week` and `minutes_active` (you'll need to average by week first — see the Guided notebook).

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

weekly_avg = weekly.groupby("week", as_index=False)["minutes_active"].mean()

fig, ax = plt.subplots()

sns.lineplot(
    data=weekly_avg,
    x="week",
    y="minutes_active",
    marker="o",
    ax=ax
)

ax.set_title("Average Weekly Student Engagement Across the Semester")
ax.set_xlabel("Week")
ax.set_ylabel("Average Minutes Active")

plt.show()

# %% [markdown]
# **STAR story — Q5** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# Scope: This chart shows the average weekly engagement, measured in active minutes, for Northgate students across weeks 1–16 of the semester.
#
# Track: I am answering how student engagement changes across the semester by comparing the average active minutes from week to week.
#
# Articulate: Student engagement stays fairly consistent at around 210–212 minutes per week for most of the semester. There is very little change from weeks 1–8 and weeks 10–16, showing a generally stable level of engagement.
#
# Respond: Week 9 stands out because average engagement suddenly drops significantly, before returning to around 210 minutes in week 10. This could represent something unusual about that week, such as a break, missing data, or another event. I would next investigate what happened during week 9 and check whether the low value reflects actual student behavior or a data issue.

# %% [markdown]
# # Part B — Your own question (open)
# Pose **one question of your own** about the Northgate students, choose the chart that answers it, build it, label it, and write its STAR story. Going beyond Part A is rewarded — a per-student line chart, a violin plot, or a chart of a messier column are all fair game.
#
# **Your question:** Does working more hours per week relate to students' likelihood of dropping out?

# %%
# Copy the closest cell from the Guided notebook, then fill in the blanks.
#
#   fig, ax = plt.subplots()
#   sns.__________(data=________, x="__________", color=NAVY, ax=ax)   # which chart? which column(s)?
#   ax.set_title("__________")
#   ax.set_xlabel("__________")
#   ax.set_ylabel("__________")
#   plt.show()

# --- your code below ---

fig, ax = plt.subplots()

sns.boxplot(
    data=students,
    x="dropped_out",
    y="work_hours_per_week",
    ax=ax
)

ax.set_title("Weekly Work Hours by Student Dropout Status")
ax.set_xlabel("Dropped Out (0 = No, 1 = Yes)")
ax.set_ylabel("Work Hours per Week (hours)")

plt.show()

# %% [markdown]
# **STAR story — Part B** *(write in your own words)*
#
# - **Scope —** what does this chart show? (which column(s), which students)
# - **Track —** which question are you answering?
# - **Articulate —** what does the chart actually say? (typical value, spread, shape, comparison, or trend)
# - **Respond —** anything odd or unexpected? what would you look at next? *(note it — you don't fix it this week)*

# %% [markdown]
# Scope: This chart shows weekly work hours for Northgate students, separated by whether they dropped out. Group 0 represents students who did not drop out, while group 1 represents students who did.
#
# Track: I am answering whether weekly work hours differ between students who dropped out and students who did not.
#
# Articulate: The typical student in both groups works about 18 hours per week. The middle 50% of students in both groups is also very similar, roughly 10–25 hours per week. Overall, the distributions look quite similar, suggesting that weekly work hours alone do not show a large difference between the two groups.
#
# Respond: There is an unusual negative value in the non-dropout group, where work hours go below 0 hours, which does not make sense for weekly work hours and may indicate a data-quality issue. I would next investigate that value and compare work hours with other factors, such as engagement or final GPA, to see whether they provide more information about dropout status.

# %% [markdown]
# # Before you submit — checklist
# - [ ] The notebook **runs top to bottom** with no errors (Runtime → Restart and run all).
# - [ ] All **6 charts** are present, each with a title, labeled axes, and units/legend where needed.
# - [ ] Each chart has a **complete STAR story**, including any exceptions you spotted.
# - [ ] Part B question is written in and answered.
# - [ ] Pushed to **GitHub**, and the **GitHub link** is submitted in Canvas.
#
# **Rubric (70 pts):** chart choice 10 · correct build 20 · labeling 10 · STAR reading 18 · Part B question 4 · submission & professionalism 8.
