# %% [markdown]
# <a href="https://colab.research.google.com/github/starryubin/Gauri_INFO4670_Fall2026/blob/main/in_class_exercise_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #My first python code for NLP

# %%
print("Hello world!")
# Out:
# Hello world!
